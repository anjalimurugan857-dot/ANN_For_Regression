# %% [markdown]
# ## Problem Statement

# %% [markdown]
#  ### Build a ML Model that predict the median house price based on 13 socio-Ecinomic and property-Related features from the BOSTON Housing dataset.

# %% [markdown]
# ### 1. Import Necessary Libraries.

# %%
import numpy as np
from tensorflow.keras.datasets import boston_housing
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### 2. Import Data set.

# %%
(X_train,y_train), (X_test,y_test) = boston_housing.load_data()

# %% [markdown]
# ### 3. Data Understanding.

# %%
print(X_train.shape,y_train.shape)
# Out:
# (404, 13) (404,)

# %%
print(X_test.shape,y_test.shape)
# Out:
# (102, 13) (102,)

# %% [markdown]
# ### 4. Data Preparation.

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
X_train.std().round(),X_train.mean().round()
# Out:
# (np.float64(1.0), np.float64(0.0))

# %%
X_test.std().round(),X_test.mean().round()
# Out:
# (np.float64(1.0), np.float64(-0.0))

# %% [markdown]
# ### 5. Model Building.

# %%
model = Sequential()

model.add(Dense(64,activation='relu',input_shape=(13,)))
model.add(Dense(32,activation='relu'))
model.add(Dense(16,activation='relu'))

model.add(Dense(1))

# %%
model.compile(optimizer='adam',loss='mse',metrics=['mae'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# ### 6. Model Training || 7. Model Testing || 8. Model Evalution

# %%
model.fit(X_train,y_train,batch_size=16,epochs=100,validation_split=0.2,verbose=1)
# Out:
# Epoch 1/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 522.7975 - mae: 21.0764 - val_loss: 546.5145 - val_mae: 21.6904
# Epoch 2/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 433.1524 - mae: 19.0531 - val_loss: 414.6449 - val_mae: 18.6592
# Epoch 3/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 274.2074 - mae: 14.7576 - val_loss: 215.8877 - val_mae: 12.4531
# Epoch 4/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 112.1344 - mae: 8.3694 - val_loss: 91.2744 - val_mae: 7.5039
# Epoch 5/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 61.8625 - mae: 5.7626 - val_loss: 58.1549 - val_mae: 5.7944
# Epoch 6/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 40.0912 - mae: 4.4468 - val_loss: 40.8186 - val_mae: 4.6242
# Epoch 7/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 31.3339 - mae: 3.7678 - val_loss: 30.6765 - val_mae: 4.0199
# Epoch 8/100
# ...

# %% [markdown]
# ### 9. Model Prediction.(New Observation)

# %%
new_data = np.array([[0.02,18,2.5,0,0.45,6.5,65,4.5,1,300,15,300,5]])

new_data = scaler.transform(new_data)

predicion = model.predict(new_data)

print("Predicion House Price:",predicion)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# Predicion House Price: [[26.52768]]

# %% [markdown]
# ### THE END!!!
